# %%
# %sql
create schema if not exists formula1_catalog.control
managed location 'abfss://formula1@databrickscourseextdela.dfs.core.windows.net/control';

# %%
# %sql
create table if not exists formula1_catalog.control.batch_events
(
    batch_id int,
    event_timestamp timestamp
)

# %%
# %sql
insert into formula1_catalog.control.batch_events
values (3, current_timestamp());

# %%
display(spark.table('formula1_catalog.control.batch_events'))

# %%
# %sql

SELECT * FROM formula1_catalog.control.batch_events;
